# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# UIDAI-ENR-DETAIL-20170308.csv Untitled.ipynb

# %% [markdown]
# # Write a command to read csv file

# %%
dataset = pd.read_csv("UIDAI-ENR-DETAIL-20170308.csv")
# Out:
# /Users/rushikesh/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Find number of instances in dataset

# %%
print("Numbe of instances in dataset are "+str(dataset.shape[0]))
# Out:
# Numbe of instances in dataset are 440818

# %% [markdown]
# ## Display the datatypes of dataset

# %%
dataset.dtypes
# Out:
# Registrar                             object
# Enrolment Agency                      object
# State                                 object
# District                              object
# Sub District                          object
# Pin Code                              object
# Gender                                object
# Age                                    int64
# Aadhaar generated                      int64
# Enrolment Rejected                     int64
# Residents providing email            float64
# Residents providing mobile number      int64
# dtype: object

# %% [markdown]
# ### Top 5 instances of dataset

# %%
dataset.head()
# Out:
#         Registrar                     Enrolment Agency          State  \
# 0  Allahabad Bank                A-Onerealtors Pvt Ltd  Uttar Pradesh
# 1  Allahabad Bank         Asha Security Guard Services  Uttar Pradesh
# 2  Allahabad Bank                    SGS INDIA PVT LTD  Uttar Pradesh
# 3  Allahabad Bank  Sri Ramraja Sarkar Lok Kalyan Trust  Uttar Pradesh
# 4  Allahabad Bank                   Transmoovers India  Uttar Pradesh
#
#     District Sub District Pin Code Gender  Age  Aadhaar generated  \
# 0  Allahabad         Meja   212303      F    7                  1
# 1  Sonbhadra  Robertsganj   231213      M    8                  1
# 2  Sultanpur    Sultanpur   227812      F   13                  1
# 3     Shamli       Shamli   247775      M    6                  1
# 4  Gorakhpur     Sahjanwa   273001      M    8                  1
#
#    Enrolment Rejected  Residents providing email  \
# 0                   0                        0.0
# ...

# %% [markdown]
# ### Grouping on Categoring Variable

# %%
groupdataset=dataset.groupby(['State','District'])

# %% [markdown]
# ### Define a subset of dataset

# %%
dataset[dataset.State=="Bihar"]
# Out:
#                                                 Registrar  \
# 12      Atalji Janasnehi Directorate  Government of Ka...
# 1469                                        Bank Of India
# 1681                                        Bank Of India
# 1682                                        Bank Of India
# 2142                                        Bank Of India
# 2143                                        Bank Of India
# 2144                                        Bank Of India
# 2145                                        Bank Of India
# 2146                                        Bank Of India
# 2147                                        Bank Of India
# 2148                                        Bank Of India
# 2149                                        Bank Of India
# 2150                                        Bank Of India
# 2151                                        Bank Of India
# 2152                                        Bank Of India
# ...
